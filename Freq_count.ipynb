# %% [markdown]
# <a href="https://colab.research.google.com/github/samrutthi/ML-and-NLP-/blob/main/Freq_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download("punkt")
nltk.download('stopwords')
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import sent_tokenize
from nltk.stem import PorterStemmer
import string
from collections import Counter
from nltk.corpus import stopwords
from nltk.util import bigrams
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
with open("sample.txt","r") as file:
    content = file.read()
#print(content)
content=content.split()
count=len(content)
print(f"TOtal words in the sample is: {count}")
# Out:
# TOtal words in the sample is: 2876

# %%
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
print("tokens:",tokens)
# Out:
# tokens: ['Good', 'afternoon', 'everyone', '.', 'This', 'is', 'Preprocessing', 'Paragraphs', ',', 'A', 'Beginner', "'s", 'Guide', '.', 'If', 'you', "'ve", 'trickled', 'in', ',', 'the', 'slides', 'are', 'posted', 'on', 'the', 'session', 'notes', 'so', 'you', 'can', 'download', 'and', 'follow', 'along', 'there', 'and', 'there', "'s", 'a', 'GitHub', 'repo', ',', 'a', 'sample', 'one', 'in', 'the', 'slides', 'as', 'well', '.', 'We', "'ll", 'pause', 'on', 'the', 'link', 'when', 'we', 'get', 'to', 'it', 'in', 'a', 'few', 'slides', '.', 'A', 'bit', 'about', 'me', '.', 'My', 'name', 'is', 'Larry', 'Walangitan', '.', 'I', "'m", 'a', 'senior', 'developer', 'at', 'Chromatic', '.', 'This', 'is', 'how', 'you', 'can', 'find', 'me', 'on', 'the', 'web', '.', 'This', 'is', 'the', 'dog', 'that', 'my', 'wife', 'and', 'I', 'just', 'adopted', ',', 'she', 'was', 'the', 'partner', 'and', 'listened', 'to', 'me', 'practice', 'this', 'a', 'ton', 'so', 'just', 'giving', 'a', 'shout', 'out', 'to', 'her', '.', 'I'
# ...

# %%
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
lowercased_tokens=[token.lower() for token in tokens]
print("lowercased_tokens:",lowercased_tokens)
# Out:
# lowercased_tokens: ['good', 'afternoon', 'everyone', '.', 'this', 'is', 'preprocessing', 'paragraphs', ',', 'a', 'beginner', "'s", 'guide', '.', 'if', 'you', "'ve", 'trickled', 'in', ',', 'the', 'slides', 'are', 'posted', 'on', 'the', 'session', 'notes', 'so', 'you', 'can', 'download', 'and', 'follow', 'along', 'there', 'and', 'there', "'s", 'a', 'github', 'repo', ',', 'a', 'sample', 'one', 'in', 'the', 'slides', 'as', 'well', '.', 'we', "'ll", 'pause', 'on', 'the', 'link', 'when', 'we', 'get', 'to', 'it', 'in', 'a', 'few', 'slides', '.', 'a', 'bit', 'about', 'me', '.', 'my', 'name', 'is', 'larry', 'walangitan', '.', 'i', "'m", 'a', 'senior', 'developer', 'at', 'chromatic', '.', 'this', 'is', 'how', 'you', 'can', 'find', 'me', 'on', 'the', 'web', '.', 'this', 'is', 'the', 'dog', 'that', 'my', 'wife', 'and', 'i', 'just', 'adopted', ',', 'she', 'was', 'the', 'partner', 'and', 'listened', 'to', 'me', 'practice', 'this', 'a', 'ton', 'so', 'just', 'giving', 'a', 'shout', 'out', 'to', 'her
# ...

# %%
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
filtered_tokens=[token for token in lowercased_tokens if token not in string.punctuation]
print("Tokens without punctuation:", filtered_tokens)
# Out:
# Tokens without punctuation: ['good', 'afternoon', 'everyone', 'this', 'is', 'preprocessing', 'paragraphs', 'a', 'beginner', "'s", 'guide', 'if', 'you', "'ve", 'trickled', 'in', 'the', 'slides', 'are', 'posted', 'on', 'the', 'session', 'notes', 'so', 'you', 'can', 'download', 'and', 'follow', 'along', 'there', 'and', 'there', "'s", 'a', 'github', 'repo', 'a', 'sample', 'one', 'in', 'the', 'slides', 'as', 'well', 'we', "'ll", 'pause', 'on', 'the', 'link', 'when', 'we', 'get', 'to', 'it', 'in', 'a', 'few', 'slides', 'a', 'bit', 'about', 'me', 'my', 'name', 'is', 'larry', 'walangitan', 'i', "'m", 'a', 'senior', 'developer', 'at', 'chromatic', 'this', 'is', 'how', 'you', 'can', 'find', 'me', 'on', 'the', 'web', 'this', 'is', 'the', 'dog', 'that', 'my', 'wife', 'and', 'i', 'just', 'adopted', 'she', 'was', 'the', 'partner', 'and', 'listened', 'to', 'me', 'practice', 'this', 'a', 'ton', 'so', 'just', 'giving', 'a', 'shout', 'out', 'to', 'her', 'i', 'work', 'for', 'chromatic', 'we', "'re", 'a
# ...

# %%
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
stopwords=nltk.corpus.stopwords.words("english")
filtered_stokens = [token for token in filtered_tokens if token.lower() not in stopwords]
print("Tokens without stopwords:", filtered_stokens)
unique_words=set(filtered_stokens)
print("unique words:",unique_words)
# Out:
# Tokens without stopwords: ['good', 'afternoon', 'everyone', 'preprocessing', 'paragraphs', 'beginner', "'s", 'guide', "'ve", 'trickled', 'slides', 'posted', 'session', 'notes', 'download', 'follow', 'along', "'s", 'github', 'repo', 'sample', 'one', 'slides', 'well', "'ll", 'pause', 'link', 'get', 'slides', 'bit', 'name', 'larry', 'walangitan', "'m", 'senior', 'developer', 'chromatic', 'find', 'web', 'dog', 'wife', 'adopted', 'partner', 'listened', 'practice', 'ton', 'giving', 'shout', 'work', 'chromatic', "'re", 'fully', 'distributed', 'team', 'find', 'us', 'web', 'two', 'places', 'real', 'life', 'booth', '516', "'m", 'going', 'pause', 'second', 'case', 'people', 'want', 'check', 'sample', 'module', 'preprocessing', 'paragraphs', 'note', 'case', 'sensitive', "'s", 'git.io/fjf6y', "n't", 'use', 'proper', 'casing', 'sometime', '--', 'last', 'session', 'gave', 'talk', "'s", 'like', 'view', 'dependency', 'aware', "'m", 'going', 'leave', 'seconds', "'ll", 'stop', 'start', "'re", 'going', 
# ...

# %%
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
stopwords=nltk.corpus.stopwords.words("english")
filtered_stokens = [token for token in filtered_tokens if token.lower() not in stopwords]

# %%
from nltk.util import ngrams
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
stopwords=nltk.corpus.stopwords.words("english")
lowercased_tokens=[token.lower() for token in tokens]
filtered_tokens=[token for token in lowercased_tokens if token not in string.punctuation]
filtered_stokens = [token for token in filtered_tokens if token.lower() not in stopwords]
unique_words=set(filtered_stokens)
bigrams = list(ngrams(filtered_stokens, 2))
print("Bigrams:", bigrams)
# Out:
# Bigrams: [('good', 'afternoon'), ('afternoon', 'everyone'), ('everyone', 'preprocessing'), ('preprocessing', 'paragraphs'), ('paragraphs', 'beginner'), ('beginner', "'s"), ("'s", 'guide'), ('guide', "'ve"), ("'ve", 'trickled'), ('trickled', 'slides'), ('slides', 'posted'), ('posted', 'session'), ('session', 'notes'), ('notes', 'download'), ('download', 'follow'), ('follow', 'along'), ('along', "'s"), ("'s", 'github'), ('github', 'repo'), ('repo', 'sample'), ('sample', 'one'), ('one', 'slides'), ('slides', 'well'), ('well', "'ll"), ("'ll", 'pause'), ('pause', 'link'), ('link', 'get'), ('get', 'slides'), ('slides', 'bit'), ('bit', 'name'), ('name', 'larry'), ('larry', 'walangitan'), ('walangitan', "'m"), ("'m", 'senior'), ('senior', 'developer'), ('developer', 'chromatic'), ('chromatic', 'find'), ('find', 'web'), ('web', 'dog'), ('dog', 'wife'), ('wife', 'adopted'), ('adopted', 'partner'), ('partner', 'listened'), ('listened', 'practice'), ('practice', 'ton'), ('ton', 'giving'), ('givi
# ...

# %%
from nltk import FreqDist
bigram_freq = FreqDist(bigrams)
print("Most common bigrams:", bigram_freq.most_common(3))
# Out:
# Most common bigrams: [(("'re", 'going'), 15), (('paragraph', 'type'), 11), (('let', "'s"), 7)]

# %%
with open("sample.txt","r")as file:
    content=file.read()
tokens=nltk.word_tokenize(content)
stopwords=nltk.corpus.stopwords.words("english")
filtered_stokens = [token for token in filtered_tokens if token.lower() not in stopwords]
print("Tokens without stopwords:", filtered_stokens)
# Out:
# Tokens without stopwords: ['good', 'afternoon', 'everyone', 'preprocessing', 'paragraphs', 'beginner', "'s", 'guide', "'ve", 'trickled', 'slides', 'posted', 'session', 'notes', 'download', 'follow', 'along', "'s", 'github', 'repo', 'sample', 'one', 'slides', 'well', "'ll", 'pause', 'link', 'get', 'slides', 'bit', 'name', 'larry', 'walangitan', "'m", 'senior', 'developer', 'chromatic', 'find', 'web', 'dog', 'wife', 'adopted', 'partner', 'listened', 'practice', 'ton', 'giving', 'shout', 'work', 'chromatic', "'re", 'fully', 'distributed', 'team', 'find', 'us', 'web', 'two', 'places', 'real', 'life', 'booth', '516', "'m", 'going', 'pause', 'second', 'case', 'people', 'want', 'check', 'sample', 'module', 'preprocessing', 'paragraphs', 'note', 'case', 'sensitive', "'s", 'git.io/fjf6y', "n't", 'use', 'proper', 'casing', 'sometime', '--', 'last', 'session', 'gave', 'talk', "'s", 'like', 'view', 'dependency', 'aware', "'m", 'going', 'leave', 'seconds', "'ll", 'stop', 'start', "'re", 'going', 
# ...

# %%
filtered_stokens= ['good', 'afternoon', 'everyone', 'preprocessing', 'paragraphs', 'beginner', "'s", 'guide', "'ve", 'trickled', 'slides', 'posted', 'session', 'notes', 'download', 'follow', 'along', "'s", 'github', 'repo', 'sample', 'one', 'slides', 'well', "'ll", 'pause', 'link', 'get', 'slides', 'bit', 'name', 'larry', 'walangitan', "'m", 'senior', 'developer', 'chromatic', 'find', 'web', 'dog', 'wife', 'adopted', 'partner', 'listened', 'practice', 'ton', 'giving', 'shout', 'work', 'chromatic', "'re", 'fully', 'distributed', 'team', 'find', 'us', 'web', 'two', 'places', 'real', 'life', 'booth', '516', "'m", 'going', 'pause', 'second', 'case', 'people', 'want', 'check', 'sample', 'module', 'preprocessing', 'paragraphs', 'note', 'case', 'sensitive', "'s", 'git.io/fjf6y', "n't", 'use', 'proper', 'casing', 'sometime', '--', 'last', 'session', 'gave', 'talk', "'s", 'like', 'view', 'dependency', 'aware', "'m", 'going', 'leave', 'seconds', "'ll", 'stop', 'start', "'re", 'going', 'go', 'talk', 'outcomes', 'talk', 'wanted', 'start', 'want', 'leave', 'talk', 'first', 'would', 'able', 'preprocess', 'paragraphs', 'structure', 'preprocessing', 'methods', 'talk', 'quite', 'opinionated', 'like', 'things', 'take', 'grain', 'salt', 'steps', "'re", 'going', 'go', 'apply', 'situation', "'re", 'using', 'paragraphs', 'also', "n't", 'worked', 'render', 'arrays', 'going', 'chance', 'dive', 'custom', 'render', 'arrays', 'twig', 'templates', 'also', 'really', 'use', 'case', 'everyone', 'familiar', 'reference', 'entities', 'fields', 'reference', 'nodes', 'taxonomy', 'terms', 'pulling', 'data', 'twig', 'templates', 'finally', 'maybe', 'important', 'one', "'re", 'debugging', 'without', 'running', 'memory', 'getting', 'white', 'screen', 'death', "'s", "'re", 'going', 'going', 'today', 'prereqs', 'familiarity', 'drupal', '8', 'twig', 'php', 'paragraphs', 'module', "n't", 'super', 'familiar', "'re", 'going', 'really', 'quick', 'overview', 'paragraphs', 'paragraphs', 'module', 'gives', 'us', 'entity', 'configurable', 'fields', 'different', 'types', 'set', 'multiple', 'different', 'types', 'paragraphs', 'also', 'uses', 'view', 'mode', 'use', 'view', 'modes', 'control', 'way', 'content', 'displayed', 'purposes', 'talk', 'since', "'re", 'talking', 'preprocessing', 'want', 'full', 'control', 'way', 'markup', 'gets', 'generated', 'page', 'paragraph', 'view', 'modes', 'cool', "'re", 'going', 'gloss', 'today', 'drupal.org', 'screenshot', 'looks', 'like', "'re", 'familiar', 'several', 'different', 'paragraphs', 'first', 'one', 'text', 'paragraph', 'couple', 'fields', 'quote', 'paragraph', 'finally', 'slideshow', 'see', 'editor', 'select', 'different', 'paragraph', 'types', 'drag', 'around', 'page', 'editors', 'full', 'control', 'creating', 'dynamic', 'experiences', 'set', 'content', 'type', "'s", 'visual', 'representation', 'paragraph', 'thought', 'left', 'right', 'looks', 'like', 'web', 'page', "'s", 'dissected', 'side', 'component', 'builds', 'web', 'page', 'would', 'look', 'like', "'re", 'making', 'content', 'really', 'strong', 'use', 'case', 'using', 'paragraphs', 'found', 'professionally', 'component', 'library', "'re", 'familiar', 'component', 'libraries', 'component', 'library', 'breaks', 'different', 'parts', 'make', 'web', 'design', 'smaller', 'isolated', 'chunks', 'goal', 'encapsulate', 'components', 'markups', 'styles', 'behavior', 'html', 'css', 'javascript', 'easily', 'mixed', 'matched', 'across', 'variety', 'templates', 'contexts', 'makes', 'easier', 'maintain', 'consistency', 'maintainability', 'design', 'system', 'take', 'component', 'library', 'structure', 'pair', 'paragraph', 'preprocess', 'paragraph', 'reflect', 'markup', 'exactly', 'let', "'s", 'take', 'look', 'examples', 'looks', 'like', 'component', 'front-end', 'developer', 'created', 'component', 'library', 'bottom', 'see', 'markup', 'need', "'s", 'going', 'look', 'like', "'s", 'rendered', 'page', "'re", 'creating', 'paragraph', 'mimic', 'exactly', 'pull', 'create', 'fields', 'create', 'sort', 'component', 'page', 'blockquote', 'would', 'need', 'field', 'quote', 'one', 'citation', 'source', 'one', 'attribution', "'s", 'another', 'example', 'audio', 'paragraph', 'couple', 'fields', 'would', 'need', 'paragraph', 'link', 'audio', 'source', 'label', 'description', 'could', 'plug', 'values', 'fields', 'paragraph', 'markup', 'render', 'page', 'goal', "'re", 'aiming', 'towards', 'talk', 'first', 'let', "'s", 'go', 'back', 'talk', 'preprocessing', 'first', 'main', 'use', 'case', 'see', 'preprocessing', 'data', 'transformation', 'something', 'editor', 'user', 'site', 'creating', 'node', "'re", 'creating', 'content', 'want', 'something', "n't", 'want', 'display', 'page', 'preprocessing', 'gives', 'us', 'ability', 'another', 'component', 'separation', 'concerns', 'logic', 'live', 'outside', 'template', 'twig', 'templates', 'given', 'lot', 'different', 'methods', 'template', 'would', 'allow', 'us', 'transformations', 'filtering', 'really', 'cool', 'things', 'great', 'developer', "'s", 'coming', 'board', "n't", 'super', 'familiar', 'twig', 'familiar', 'php', 'keeping', 'sort', 'display', 'logic', 'separate', 'super', 'helpful', 'finally', 'customization', 'main', 'piece', 'preprocessing', 'custom', 'markup', 'render', 'arrays', "'re", 'creating', 'paragraph', 'type', 'preprocessing', 'recipe', 'think', 'way', 'every', 'single', 'paragraph', 'type', "'re", 'going', 'apply', 'steps', 'preprocess', 'first', 'couple', 'things', 'need', 'make', 'sure', 'download', 'install', 'paragraphs', 'module', 'configure', 'new', 'paragraph', 'create', 'custom', 'module', 'sample', 'code', 'base', 'github', 'take', 'take', 'look', 'please', 'install', 'something', "'s", 'totally', 'learning', 'purposes', 'preprocessing', 'recipe', 'four', 'steps', 'paragraph', 'type', 'defined', 'hook', 'theme', 'module', 'second', 'preprocessing', 'going', 'handled', 'class', "'re", 'familiar', 'object-oriented', 'programming', 'think', 'class', 'blueprint', 'step', 'three', 'paragraph', 'type', 'corresponding', 'method', 'inside', 'class', 'functions', 'preprocess', 'one', 'paragraph', 'types', 'set', 'configuration', 'finally', 'paragraph', 'type', 'corresponding', 'twig', 'template', 'preprocessing', 'structured', 'markup', 'comes', 'together', 'wraps', 'four', 'steps', 'keep', 'mind', 'throughout', 'let', "'s", 'start', 'step', 'one', 'hook_theme', 'module', 'custom', 'module', 'created', 'three', 'different', 'array', 'keys', 'need', 'aware', 'first', 'base', 'hook', 'second', 'variables', "'re", 'going', 'creating', 'finally', 'path', 'template', 'inside', 'hook_theme', 'function', 'paragraph', 'foo', 'machine', 'name', 'like', 'example', 'machine', 'name', "'re", 'calling', 'base', 'hook', 'variables', 'path', 'let', "'s", 'define', 'base', 'hook', 'journey', 'working', 'paragraphs', 'probably', 'critical', 'component', 'unlocking', 'preprocessing', 'base', 'hooks', "'re", 'defined', 'another', 'module', "'s", 'theme', 'paragraphs', 'module', 'contributed', 'module', 'base', 'hook', 'use', 'extend', "'re", 'going', 'call', 'base', 'hook', 'paragraph', 'hook', 'theme', 'allow', 'us', 'override', 'extend', 'base', 'hook', 'custom', 'variables', 'assign', 'custom', 'template', 'variable', 'next', 'one', "'re", 'defining', 'custom', 'variables', 'need', 'coincide', 'either', 'fields', "'ve", 'defined', 'paragraph', 'pieces', 'page', 'component', 'library', 'mentioned', 'earlier', 'finally', 'path', 'paragraph', "'s", 'custom', 'template', 'lives', 'way', 'set', 'reflective', 'set', 'sample', 'repo', 'github', "'re", 'familiar', "'s", 'happening', "'re", 'concatenating', 'path', 'available', 'hook_theme', 'custom', 'strings', 'know', 'exactly', 'template', 'lives', 'preprocessing', 'class', "'ve", 'set', 'src/paragraphpreprocessor.php', 'class', 'defined', 'way', "'s", 'pretty', 'opinionated', 'someone', "'s", 'coming', 'project', "'re", 'working', 'another', 'developer', 'want', 'know', 'preprocessing', 'happening', 'paragraph', 'put', 'everything', 'recommend', 'setup', "'s", 'one', 'class', 'handles', 'methods', 'preprocessing', 'paragraph', 'types', 'specifically', 'preprocess', 'method', 'example', 'module', 'preprocessfoo', "'s", 'retrieving', 'data', 'returning', 'variables', 'reference', 'render', 'array', 'defined', 'hook_theme', 'basic', 'level', 'preprocessing', 'methods', 'preparing', 'variables', 'templates', 'example', 'preprocessfoo', 'method', 'would', 'look', 'like', 'see', "'ve", 'defined', 'content', 'since', "'s", 'main', 'array', 'value', 'interested', 'inside', 'dig', 'deeper', 'get', 'field', 'names', 'using', 'machine', 'names', 'go', 'even', 'pull', 'markup', 'text', 'keys', "'ve", 'done', 'comments', 'would', 'look', 'like', 'output', 'paragraph', 'template', 'paragraph', 'template', 'structure', 'follows', 'machine', 'names', 'paragraph', '--', 'foo.html.twig', 'inside', 'see', 'defined', 'couple', 'divs', 'headers', 'steps', "'ve", 'gone', 'one', 'basic', 'example', 'paragraph', "'ve", 'created', 'next', 'thing', "'m", 'going', 'go', 'maybe', 'bit', 'advanced', "'re", 'going', 'optimize', 'workflow', 'right', "'s", 'bit', 'easier', 'maintain', 'future', 'going', 'creating', 'service', 'custom', 'module', 'services.yml', 'file', "'re", 'going', 'create', 'chromatic_paragraphs.paragraphs_preprocess', 'service', 'going', 'call', 'class', 'created', 'handle', 'preprocessing', 'paragraphs', "'ve", 'done', "'s", 'bit', 'easier', 'use', 'developer', "'s", 'bit', 'structured', 'also', 'gives', 'us', 'ability', 'run', 'unit', 'tests', 'future', 'services.yml', 'file', 'would', 'set', "'re", 'thinking', '--', "'s", 'missing', 'piece', 'link', 'module', 'file', 'need', 'call', 'actual', 'hook', 'invoke', 'methods', 'template_preprocess_paragraph_foo', 'inside', 'module', 'file', 'might', 'see', 'think', 'usually', "'s", 'hook_preprocess', 'sort', 'thing', "'re", 'calling', 'template', 'preprocess', "'re", 'specifically', 'template', 'preprocess', 'prepares', 'variables', 'us', 'available', 'drupal', '8', 'api', 'want', 'return', 'render', 'array', 'variables', "'ve", 'created', 'hook_theme', "'re", 'going', 'call', 'new', 'service', 'inside', 'function', 'inside', 'module', 'bit', 'things', 'top', 'defining', 'constant', 'service', "'re", 'going', 'call', 'customer', 'service', 'inside', 'template_preprocess_paragraph_foo', 'inside', "'re", 'going', 'prepare', 'variables', 'twig', 'template', 'method', "'s", 'class', "'s", 'everything', 'connects', 'creating', 'class', 'methods', 'calling', 'template', 'function', 'allows', 'us', 'access', 'methods', 'generate', 'markup', 'want', 'twig', 'template', 'really', 'quite', 'use', 'cases', 'unique', 'nested', 'entities', 'essentially', "'re", 'retrieving', 'data', 'entity', 'references', 'always', 'follow', 'two', 'steps', 'first', 'load', 'reference', 'entity', 'whether', "'s", 'node', 'taxonomy', 'term', 'user', 'return', 'values', 'note', "'s", 'pretty', 'simple', 'let', "'s", 'take', 'look', 'apologize', 'text', 'little', 'bit', 'small', "'re", 'first', 'checking', 'make', 'sure', 'field', "'re", 'referencing', 'populated', 'actual', 'data', 'dig', 'deeper', 'data', 'get', 'value', "'m", 'checking', 'reference', 'node', 'exists', "'m", 'going', 'pull', 'header', 'field', 'assign', 'header', 'variable', 'set', 'putting', 'together', 'let', "'s", 'go', 'steps', "'ve", 'done', 'first', 'paragraph', 'type', "'ve", 'defined', 'one', 'hook_theme', 'step', 'two', 'preprocessing', 'handled', 'class', 'step', 'step', 'two', 'set', 'step', 'three', 'every', 'single', 'paragraph', 'type', 'corresponding', 'method', 'finally', 'paragraph', 'type', 'corresponding', 'twig', 'template', 'want', 'clarify', 'create', 'paragraphs', 'exclude', 'custom', 'preprocessing', "n't", 'need', 'custom', 'preprocessing', "n't", 'specifically', 'want', 'preprocess', 'paragraphs', 'goes', 'wrong', 'things', "n't", 'working', 'correctly', 'run', 'issues', 'memory', "'re", 'using', 'kint', 'things', "n't", 'work', 'two', 'tools', 'served', 'well', 'one', 'tools', 'front', 'end', 'inside', 'actual', 'templates', 'twig', 'vardumper', 'module', "'s", 'great', 'tool', 'second', 'one', 'symfony', 'component', 'vardumper', 'added', 'way', 'composer', 'projects', 'found', 'much', 'better', 'performance', 'kint', 'past', 'two', 'personal', 'tools', 'enjoy', 'using', "'m", 'developing', 'paragraphs', 'another', 'trick', 'one', 'drupal', 'slacks', 'morton', 'constantly', 'running', 'memory', 'paste', 'piece', 'code', 'twig', 'template', 'sort', 'template', "'ll", 'go', 'two', 'levels', 'deep', 'render', 'array', 'see', 'keys', 'values', 'available', "'s", 'less', 'loaded', 'memory', 'debug', 'bit', 'easier', 'white', 'screen', 'death', 'last-ditch', 'option', 'ones', "n't", 'work', "'re", 'probably', 'thinking', "n't", 'theme', 'create', 'custom', 'module', 'comes', 'personal', 'experience', 'shared', 'codebase', 'want', 'share', 'paragraphs', 'across', 'sites', 'want', 'branding', 'output', 'different', "'re", 'preprocessing', 'things', 'different', 'themes', 'manage', 'actual', 'theming', 'layer', 'steps', 'would', 'wanted', 'theme', 'single', 'layer', 'going', 'similar', "'ve", 'done', 'paragraphs', 'custom', 'module', 'let', "'s", 'take', 'look', 'looks', 'like', 'theme', 'step', 'one', 'preprocessing', 'going', 'handled', '.theme', 'file', 'step', 'two', 'going', 'instead', 'defining', 'class', "'re", 'going', 'hook_theme', "'re", 'going', 'make', 'sure', 'paragraph', 'type', 'defined', 'hook_theme', 'step', 'three', 'going', 'making', 'sure', "'s", 'template', 'override', 'function', 'corresponds', 'paragraph', 'type', 'set', 'finally', 'paragraph', 'type', 'going', 'corresponding', 'twig', 'template', "'s", 'pretty', 'quick', 'overview', 'rundown', 'would', 'preprocessing', 'custom', 'module', 'theme', "'ve", 'set', 'aside', 'time', 'questions', 'answers', 'real', 'quick', 'contributions', 'friday', 'sure', 'check', 'sure', 'leave', 'survey', 'results', 'time', 'questions', 'answers', 'anyone', 'thanks']
term_frequencies = {}

# Loop through each term in filtered_tokens
for term in filtered_tokens:
    # If the term is already in the dictionary, increment its count
    if term in term_frequencies:
        term_frequencies[term] += 1
    # If the term is not in the dictionary, add it with a count of 1
    else:
        term_frequencies[term] = 1

# Print the frequency of each term
print("Term frequencies:", term_frequencies)
# Out:
# Term frequencies: {'good': 1, 'afternoon': 1, 'everyone': 2, 'this': 56, 'is': 74, 'preprocessing': 24, 'paragraphs': 19, 'a': 105, 'beginner': 1, "'s": 40, 'guide': 1, 'if': 19, 'you': 50, "'ve": 13, 'trickled': 1, 'in': 57, 'the': 113, 'slides': 3, 'are': 21, 'posted': 1, 'on': 22, 'session': 2, 'notes': 1, 'so': 15, 'can': 24, 'download': 2, 'and': 70, 'follow': 2, 'along': 1, 'there': 10, 'github': 3, 'repo': 2, 'sample': 4, 'one': 15, 'as': 8, 'well': 2, 'we': 98, "'ll": 3, 'pause': 2, 'link': 3, 'when': 11, 'get': 3, 'to': 87, 'it': 48, 'few': 4, 'bit': 8, 'about': 3, 'me': 4, 'my': 5, 'name': 3, 'larry': 1, 'walangitan': 1, 'i': 27, "'m": 7, 'senior': 1, 'developer': 5, 'at': 9, 'chromatic': 2, 'how': 8, 'find': 2, 'web': 5, 'dog': 1, 'that': 95, 'wife': 1, 'just': 26, 'adopted': 1, 'she': 1, 'was': 2, 'partner': 1, 'listened': 1, 'practice': 1, 'ton': 1, 'giving': 1, 'shout': 1, 'out': 6, 'her': 1, 'work': 3, 'for': 36, "'re": 42, 'fully': 1, 'distributed': 1, 'team': 1, 'us'
# ...
